# %%
import requests
import pandas as pd

# %%
url = "https://dummyjson.com/carts"

# %%
data = requests.get(url)
data.status_code
# Out:
# 200

# %%
cart = data.json()
cart
# Out:
# {'carts': [{'id': 1,
#    'products': [{'id': 162,
#      'title': 'Blue Frock',
#      'price': 29.99,
#      'quantity': 4,
#      'total': 119.96,
#      'discountPercentage': 12.13,
#      'discountedTotal': 105.41,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/tops/blue-frock/thumbnail.webp'},
#     {'id': 113,
#      'title': 'Generic Motorcycle',
#      'price': 3999.99,
#      'quantity': 3,
#      'total': 11999.97,
#      'discountPercentage': 12.1,
#      'discountedTotal': 10547.97,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/motorcycle/generic-motorcycle/thumbnail.webp'},
#     {'id': 122,
#      'title': 'iPhone 6',
#      'price': 299.99,
#      'quantity': 3,
#      'total': 899.97,
#      'discountPercentage': 6.69,
#      'discountedTotal': 839.76,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/smartphones/iphone-6/thumbnail.webp'},
#     {'id': 138,
#      'title': 'Baseball Ball',
#      'price': 8.99,
# ...

# %%
type (cart)
# Out:
# dict

# %%
cart_data = cart["carts"]
cart_data
# Out:
# [{'id': 1,
#   'products': [{'id': 162,
#     'title': 'Blue Frock',
#     'price': 29.99,
#     'quantity': 4,
#     'total': 119.96,
#     'discountPercentage': 12.13,
#     'discountedTotal': 105.41,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/tops/blue-frock/thumbnail.webp'},
#    {'id': 113,
#     'title': 'Generic Motorcycle',
#     'price': 3999.99,
#     'quantity': 3,
#     'total': 11999.97,
#     'discountPercentage': 12.1,
#     'discountedTotal': 10547.97,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/motorcycle/generic-motorcycle/thumbnail.webp'},
#    {'id': 122,
#     'title': 'iPhone 6',
#     'price': 299.99,
#     'quantity': 3,
#     'total': 899.97,
#     'discountPercentage': 6.69,
#     'discountedTotal': 839.76,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/smartphones/iphone-6/thumbnail.webp'},
#    {'id': 138,
#     'title': 'Baseball Ball',
#     'price': 8.99,
#     'quantity': 2,
#     'total': 17.98,
# ...

# %%
type(cart_data)
# Out:
# list

# %%
data_cart = pd.json_normalize(cart_data)
cart_data
# Out:
# [{'id': 1,
#   'products': [{'id': 162,
#     'title': 'Blue Frock',
#     'price': 29.99,
#     'quantity': 4,
#     'total': 119.96,
#     'discountPercentage': 12.13,
#     'discountedTotal': 105.41,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/tops/blue-frock/thumbnail.webp'},
#    {'id': 113,
#     'title': 'Generic Motorcycle',
#     'price': 3999.99,
#     'quantity': 3,
#     'total': 11999.97,
#     'discountPercentage': 12.1,
#     'discountedTotal': 10547.97,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/motorcycle/generic-motorcycle/thumbnail.webp'},
#    {'id': 122,
#     'title': 'iPhone 6',
#     'price': 299.99,
#     'quantity': 3,
#     'total': 899.97,
#     'discountPercentage': 6.69,
#     'discountedTotal': 839.76,
#     'thumbnail': 'https://cdn.dummyjson.com/product-images/smartphones/iphone-6/thumbnail.webp'},
#    {'id': 138,
#     'title': 'Baseball Ball',
#     'price': 8.99,
#     'quantity': 2,
#     'total': 17.98,
# ...

# %%
df = pd.DataFrame(cart_data)
df
# Out:
#     id                                           products      total  \
# 0    1  [{'id': 162, 'title': 'Blue Frock', 'price': 2...   13037.88
# 1    2  [{'id': 86, 'title': 'Man Short Sleeve Shirt',...     139.93
# 2    3  [{'id': 24, 'title': 'Fish Steak', 'price': 14...    1794.85
# 3    4  [{'id': 92, 'title': 'Sports Sneakers Off Whit...     689.93
# 4    5  [{'id': 161, 'title': 'Samsung Galaxy Tab Whit...    1467.88
# 5    6  [{'id': 192, 'title': 'Rolex Datejust Women', ...   55453.86
# 6    7  [{'id': 56, 'title': 'Electric Stove', 'price'...    1229.86
# 7    8  [{'id': 18, 'title': 'Cat Food', 'price': 8.99...    6337.83
# 8    9  [{'id': 1, 'title': 'Essence Mascara Lash Prin...   29709.90
# 9   10  [{'id': 41, 'title': 'Tissue Paper Box', 'pric...     152.44
# 10  11  [{'id': 115, 'title': 'MotoGP CI.H1', 'price':...   61831.75
# 11  12  [{'id': 117, 'title': 'Sportbike Motorcycle', ...   37767.32
# 12  13  [{'id': 35, 'title': 'Potatoes', 'price': 2.29...      16.54
# ...

# %%
final_df = pd.json_normalize(
    cart_data, 
    record_path=['products'], 
    meta=['id', 'total', 'discountedTotal', 'userId', 'totalProducts', 'totalQuantity'],
    meta_prefix='cart_',
    record_prefix='product_'
)

final_df.head()
# Out:
#    product_id           product_title  product_price  product_quantity  \
# 0         162              Blue Frock          29.99                 4
# 1         113      Generic Motorcycle        3999.99                 3
# 2         122                iPhone 6         299.99                 3
# 3         138           Baseball Ball           8.99                 2
# 4          86  Man Short Sleeve Shirt          19.99                 5
#
#    product_total  product_discountPercentage  product_discountedTotal  \
# 0         119.96                       12.13                   105.41
# 1       11999.97                       12.10                 10547.97
# 2         899.97                        6.69                   839.76
# 3          17.98                        1.71                    17.67
# 4          99.95                        6.83                    93.12
#
#                                    product_thumbnail cart_id cart_total  \
# ...

# %%
df_product = pd.DataFrame(final_df)
df_product
# Out:
#      product_id           product_title  product_price  product_quantity  \
# 0           162              Blue Frock          29.99                 4
# 1           113      Generic Motorcycle        3999.99                 3
# 2           122                iPhone 6         299.99                 3
# 3           138           Baseball Ball           8.99                 2
# 4            86  Man Short Sleeve Shirt          19.99                 5
# ..          ...                     ...            ...               ...
# 109         135                 Vivo V9         299.99                 2
# 110         126       Oppo F19 Pro Plus         399.99                 1
# 111          77           Yellow Peeler           5.99                 1
# 112           3         Powder Canister          14.99                 5
# 113         170         Durango SXT RWD       36999.99                 5
#
#      product_total  product_discountPercentage  product_discountedTotal  \
# ...

# %%
final_df.to_csv("final_cart_data.csv", index=False)

# %%
# Save the data directly as a modern Excel Workbook
final_df.to_excel("cart_data_final.xlsx", index=False)
